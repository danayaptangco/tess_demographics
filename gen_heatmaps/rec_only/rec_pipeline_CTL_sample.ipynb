# %%
#without GP
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import lightkurve as lk
import batman
from transitleastsquares import transitleastsquares
import seaborn as sns
import os
from functools import lru_cache
from itertools import product
from scipy.signal import savgol_filter

# ------------------------------------
# 1. Cached light curve loader
# ------------------------------------
@lru_cache(maxsize=10)
def get_lightcurve(tic):
    lc_collection = lk.search_lightcurve(tic, mission="TESS", author="TESS-SPOC", cadence="long").download_all(quality_bitmask="hard")
    if lc_collection is None or len(lc_collection) == 0:
        return None
    
    lc = lc_collection.stitch().remove_nans()



    # plt.plot(lc.time.value, lc.flux.value, 'k.', markersize=1, alpha=0.5)
    # plt.show()


    return lc.to_pandas().reset_index()

# ------------------------------------
# 2. Flare masking: ±3hr from >5σ events
# ------------------------------------
def mask_flares(df):
    median = df['flux'].median()
    std = df['flux'].std()
    threshold = median + 5 * std
    flare_times = df.loc[df['flux'] > threshold, 'time'].values

    def within_3hr(t):
        return np.any(np.abs(flare_times - t) <= 0.125)

    flare_mask = df['time'].apply(within_3hr)
    return df[~flare_mask].reset_index(drop=True)


# 4. Run TLS detection for a single injection
# ------------------------------------
def run_tls(tic, time, flux):
    # cadence_days = time[1] - time[0]
    # duration_days = 2
    # wl = int(np.round(duration_days / cadence_days))
    # if wl % 2 == 0:
    #     wl += 1  # make it odd

    # print(wl)
    # flux_filter = savgol_filter(flux, wl, 2)
    # flux = flux / flux_filter

    ##LC PLOT
    # plt.plot(time, flux, 'k.', markersize=1, alpha=0.5)
    # plt.title(f"Lightcurve for {tic}, TOI {toi}")
    # plt.show()

    if len(time) == 0 or len(flux) == 0:
        return False
    tls = transitleastsquares(time, flux)
    result = tls.power(period_max = 25)

    powers = result.power
    periods = result.periods

    periodogram = pd.DataFrame({
        'period': periods,
        'power': powers
    })

    power_7_periods = periodogram[periodogram['power'] > 7]['period'].values
    print(f"TLS Periods with power > 7: {power_7_periods}")
    power_7_power = periodogram[periodogram['power'] > 7]['power'].values


    # print(f"{tic}, FAP: {result.FAP}, SDE: {result.SDE}, True Period: {true_period}")
    # # Mark as found if period matches true period or a simple alias (1/2x, 2x, 1/3x, 3x, etc.)
    # aliases = [true_period, true_period / 2, true_period * 2, true_period / 3, true_period * 3]
    # #found = result.FAP < 1e-4 and any(0.99 * alias < result.period < 1.01 * alias for alias in aliases)
    # found = any(0.99 * alias < hp < 1.01 * alias for hp in power_7_periods for alias in aliases)


    # alias_found = any(0.99 * alias < result.period < 1.01 * alias for alias in aliases)
    # print(f"Detection found: {found}")
    # if alias_found == True and found == False:
    #     print(f"True transit or alias found, but high FAP: {alias_found}")
    # #print("TLS Transit duration (hours):", result.duration * 24)


    # #TLS phase fold
    # plt.figure()
    # plt.scatter(result.folded_phase, result.folded_y, color='blue', s=10, alpha=0.5,)
    # plt.plot(result.model_folded_phase, result.model_folded_model, color='red')
    # plt.title(f"TLS Phase Folded Lightcurve for {tic}, TOI {toi}")
    # plt.xlabel('Phase')
    # plt.ylabel('Relative flux');
    # plt.show()

    #Periodogram
    # plt.figure()
    # ax = plt.gca()
    # ax.axvline(result.period, alpha=0.4, lw=3)
    # plt.xlim(np.min(result.periods), np.max(result.periods))
    # for n in range(2, 10):
    #     ax.axvline(n*result.period, alpha=0.4, lw=1, linestyle="dashed")
    #     ax.axvline(result.period / n, alpha=0.4, lw=1, linestyle="dashed")
    # plt.ylabel(r'SDE')
    # plt.xlabel('Period (days)')
    # plt.plot(result.periods, result.power, color='black', lw=0.5)
    # plt.xlim(0, max(result.periods));
    # #plt.xlim(20.8, 21.0)
    # plt.show()


    

    return result.period, result.SDE, power_7_periods, power_7_power, result.period_uncertainty, result.depth, result.rp_rs, result.FAP, result.snr

# ------------------------------------
# 5. Run detection across grid (single process)
# ------------------------------------
def run_detection_for_tic(tic):

    print(f"📥 Processing {tic}")
    lc = get_lightcurve(tic)
    if lc is None:
        print(f"❌ No light curve for {tic}")
        return pd.DataFrame()

    base_df = lc[['time', 'flux']].copy()
    base_df = mask_flares(base_df)

    time = base_df['time']
    flux = base_df['flux']
    

    # plt.plot(time, flux, 'k.', markersize=1, alpha=0.5)
    # plt.show()

    #flatten lightcurve after flare removal
    lc = lk.LightCurve(time=time, flux=flux)
    time = lc.time.value  # in days
    if len(time) < 2:
        return None

    cadence_days = time[1] - time[0]
    duration_days = 2
    wl = int(np.round(duration_days / cadence_days))
    if wl % 2 == 0:
        wl += 1  # make it odd, as required

    print(f"Cadence: {cadence_days:.5f} days, window_length: {wl}")

    lc_flat = lc.flatten(window_length=wl, polyorder=2)
    flat_df = lc_flat.to_pandas().reset_index()
    time = flat_df['time'].values
    flux = flat_df['flux'].values
    #flux = flux / np.median(flux)

    # plt.plot(time, flux, 'k.', markersize=1, alpha=0.5)
    # plt.show()


    # Get stellar parameters
    tic_id = int(tic.split()[1])
    star_params = pd.read_csv("take_two_stellar_params_CTL.csv").query(f"id == {tic_id}")
    if star_params.empty:
        print(f"⚠️ No stellar params for {tic}")
        return pd.DataFrame()

    st_radius = star_params['RAD'].values[0] #* 6.9634e8
    st_teff = star_params['teff'].values[0]
    st_tmag = star_params['tmag'].values[0]

    results = []
    tls_period, SDE_strongest,  periods_array_7, SDE_array_7, tls_period_uncertainty, tls_depth, tls_rp_rs, tls_FAP, tls_snr = run_tls(tic, time, flux)
    #detections += found

    results.append({
        'TIC': tic,
        'Stellar Radius': round(float(st_radius), 2),
        'Stellar Temperature': st_teff,
        'Stellar Magnitude': st_tmag,
        #'True Radius (Earth Radii)': round(float(true_rp_earth), 2),
        #'True Period (Days)': round(float(true_period), 4),
        #'Detection': found,
        #'Alias Detection but high FAP': alias_found,
        'TLS Period': tls_period,
        'TLS SDE strongest': SDE_strongest,
        'TLS SDE > 7 array': SDE_array_7,
        'TLS Periods array': periods_array_7,
        'TLS Period Uncertainty': tls_period_uncertainty,
        'TLS Depth': tls_depth,
        'TLS Rp/Rs': tls_rp_rs,
        'TLS FAP': tls_FAP,
        'TLS SNR': tls_snr
    })
        

    return pd.DataFrame(results)

# ------------------------------------
# 6. Save heatmap and results
# ------------------------------------
# def save_heatmap(data, tic):
#     pivot = data.pivot(index="Radius (Earth Radii)", columns="Period (Days)", values="Detection")
#     plt.figure(figsize=(8, 6))
#     sns.heatmap(pivot, cmap="viridis", vmin=0, vmax=1, cbar_kws={'label': 'Percent found'}).invert_yaxis()
#     plt.title(f"{tic} noise transit detection rate")
#     plt.xlabel("Period (Days)")
#     plt.ylabel("Radius (Earth Radii)")
#     plt.tight_layout()
#     plt.show()

#     os.makedirs("heatmap_data", exist_ok=True)
#     path = f'heatmap_data/{tic.replace(" ", "_")}_cel_heatmap.csv'
#     data.to_csv(path, index=False)
#     print(f"✅ Saved: {path}")

# ------------------------------------
# 7. Main driver
# ------------------------------------
if __name__ == "__main__":

    save_file = "./rec_results/take_two_CTL_TLS_recovery.csv"
    #save_file = './test.csv'

    # Load TIC IDs from the CSV file
    star_params = pd.read_csv("take_two_stellar_params_CTL.csv")
    #star_params = star_params.iloc[530:].reset_index(drop=True)
    print(len(star_params))
    # Filter for TOI == 7033
    #star_params = star_params[star_params["id"] == 468858510]

    #star_params = star_params[928:]
    #star_params = star_params[star_params["pl_orbper"] <= 25]
    
    #star_params = star_params.iloc[40:].reset_index(drop=True)

    #star_params = star_params.iloc[[8, 12, 25, 42, 48, 51, 52, 58, 59], :] # group 1
    #star_params = star_params.iloc[[0,9,30,35,45,58], :] # group 2
    #star_params = star_params.iloc[[13,28, 31,32,33,34,36,37,39,41,43,44 ,49], :] # group 3
        # Load existing results to check for already processed TICs
    if os.path.exists(save_file):
        existing_results = pd.read_csv(save_file)
        processed_tics = set(existing_results[existing_results['Stellar Radius'].notna()]['TIC'].values)
        print(f"Found {len(processed_tics)} already processed TICs")
    else:
        processed_tics = set()
        print("No existing results file found, starting fresh")
    
    
    #for each pair of toi and tic, there's a true period and rp_earth to run

    df_save = pd.DataFrame()
for _, row in star_params.iterrows():
    #toi = row['toi']
    tic = f"TIC {int(row['id'])}"
    #true_period = row['pl_orbper']
    #true_rp_earth = row['pl_rade']
    if tic in processed_tics:
        print(f"⏭️ Skipping {tic} - already processed")
        continue
    try:
        df_results = run_detection_for_tic(tic)

        if not df_results.empty:
            df_save = pd.concat([df_save, df_results], ignore_index=True)
        else:
            df_results = pd.DataFrame([{
                'TIC': tic,
                'Stellar Radius': None,
                'Stellar Temperature': None,
                'Stellar Magnitude': None,
                'TLS Period': None,
                'TLS SDE strongest': None,
                'TLS SDE > 7 array': None,
                'TLS Periods array': None,
                'TLS Period Uncertainty': None,
                'TLS Depth': None,
                'TLS Rp/Rs': None,
                'TLS FAP': None,
                'TLS SNR': None
            }])
        
            df_save = pd.concat([df_save, df_results], ignore_index=True)

        # ✅ Save result
        if os.path.exists(save_file):
            existing = pd.read_csv(save_file)
            existing = existing[existing['TIC'] != tic]
            updated = pd.concat([existing, df_results], ignore_index=True)
        else:
            updated = df_results
        updated.to_csv(save_file, index=False)

    except Exception as e:
        print(f"❌ Error occurred for {tic}: {e}")
        df_results = pd.DataFrame([{
                'TIC': tic,
                'Stellar Radius': None,
                'Stellar Temperature': None,
                'Stellar Magnitude': None,
                'TLS Period': None,
                'TLS SDE strongest': None,
                'TLS SDE > 7 array': None,
                'TLS Periods array': None,
                'TLS Period Uncertainty': None,
                'TLS Depth': None,
                'TLS Rp/Rs': None,
                'TLS FAP': None,
                'TLS SNR': None
            }])
        
        df_save = pd.concat([df_save, df_results], ignore_index=True)

        # ✅ Save even on error
        if os.path.exists(save_file):
            existing = pd.read_csv(save_file)
            existing = existing[existing['TIC'] != tic]
            updated = pd.concat([existing, df_results], ignore_index=True)
        else:
            updated = df_results
        updated.to_csv(save_file, index=False)
# Out:
# Warning: 35% (453/1288) of the cadences will be ignored due to the quality mask (quality_bitmask=7407).
# 875
# Found 874 already processed TICs
# ⏭️ Skipping TIC 51988363 - already processed
# ⏭️ Skipping TIC 172076858 - already processed
# ⏭️ Skipping TIC 140067408 - already processed
# ⏭️ Skipping TIC 284566637 - already processed
# ⏭️ Skipping TIC 11148069 - already processed
# ⏭️ Skipping TIC 457925111 - already processed
# ⏭️ Skipping TIC 155896956 - already processed
# 📥 Processing TIC 209428610
# ❌ Error occurred for TIC 209428610: Error in reading Data product /Users/danayaptangco/.lightkurve/cache/mastDownload/HLSP/hlsp_tess-spoc_tess_phot_0000000209428610-s0004_tess_v1_tp/hlsp_tess-spoc_tess_phot_0000000209428610-s0004_tess_v1_lc.fits of type TessLightCurve .
# This file may be corrupt due to an interrupted download. Please remove it from your disk and try again.
# ⏭️ Skipping TIC 173535874 - already processed
# ⏭️ Skipping TIC 92005981 - already processed
# ⏭️ Skipping TIC 186968731 - already processed
# ⏭️ Skipping TIC 146579468 - already processed
# ⏭️ Skipping TIC 198010547 - already processed
# ⏭️ Skipping TIC 335918986 - already processed
# ⏭️ Skipping TIC 317880236 - already processed
# ⏭️ Skipping TIC 3358442 - already processed
# ⏭️ Skipping TIC 36648057 - already processed
# ⏭️ Skipping TIC 52093014 - already processed
# ⏭️ Skipping TIC 50490788 - already processed
# ⏭️ Skipping TIC 337025463 - already processed
# ⏭️ Skipping TIC 123405412 - already processed
# ⏭️ Skipping TIC 189400940 - already processed
# ⏭️ Skipping TIC 123968788 - already processed
# ⏭️ Skipping TIC 335622798 - already processed
# ⏭️ Skipping TIC 318190759 - already processed
# ⏭️ Skipping TIC 114182302 - already processed
# ⏭️ Skipping TIC 137057529 - already processed
# ⏭️ Skipping TIC 293406130 - already processed
# ⏭️ Skipping TIC 88004701 - already processed
# ⏭️ Skipping TIC 28831845 - already processed
# ⏭️ Skipping TIC 288349615 - already processed
# ⏭️ Skipping TIC 445329573 - already processed
# ⏭️ Skipping TIC 296946921 - already processed
# ⏭️ Skipping TIC 219227008 - already processed
# ⏭️ Skipping TIC 407661994 - already processed
# ⏭️ Skipping TIC 55999985 - already processed
# ⏭️ Skipping TIC 159333380 - already processed
# ⏭️ Skipping TIC 361078666 - already processed
# ⏭️ Skipping TIC 21444273 - already processed
# ⏭️ Skipping TIC 96029337 - already processed
# ⏭️ Skipping TIC 294399068 - already processed
# ⏭️ Skipping TIC 141272004 - already processed
# ⏭️ Skipping TIC 120491166 - already processed
# ⏭️ Skipping TIC 348762301 - already processed
# ⏭️ Skipping TIC 264392781 - already processed
# ⏭️ Skipping TIC 376932590 - already processed
# ⏭️ Skipping TIC 123013596 - already processed
# ⏭️ Skipping TIC 293246399 - already processed
# ⏭️ Skipping TIC 16416020 - already processed
# ⏭️ Skipping TIC 120444672 - already processed
# ⏭️ Skipping TIC 332022805 - already processed
# ⏭️ Skipping TIC 136324903 - already processed
# ⏭️ Skipping TIC 293000359 - already processed
# ⏭️ Skipping TIC 394014255 - already processed
# ⏭️ Skipping TIC 350443738 - already processed
# ⏭️ Skipping TIC 304379558 - already processed
# ⏭️ Skipping TIC 235045630 - already processed
# ⏭️ Skipping TIC 220433100 - already processed
# ⏭️ Skipping TIC 278955132 - already processed
# ⏭️ Skipping TIC 229686485 - already processed
# ⏭️ Skipping TIC 123821258 - already processed
# ⏭️ Skipping TIC 333606239 - already processed
# ⏭️ Skipping TIC 400094112 - already processed
# ⏭️ Skipping TIC 149976276 - already processed
# ⏭️ Skipping TIC 140527996 - already processed
# ⏭️ Skipping TIC 155720275 - already processed
# ⏭️ Skipping TIC 432125911 - already processed
# ⏭️ Skipping TIC 35027579 - already processed
# ⏭️ Skipping TIC 101396997 - already processed
# ⏭️ Skipping TIC 161821169 - already processed
# ⏭️ Skipping TIC 405894687 - already processed
# ⏭️ Skipping TIC 233046489 - already processed
# ⏭️ Skipping TIC 162898041 - already processed
# ⏭️ Skipping TIC 64477826 - already processed
# ⏭️ Skipping TIC 5983532 - already processed
# ⏭️ Skipping TIC 306574570 - already processed
# ⏭️ Skipping TIC 31602748 - already processed
# ⏭️ Skipping TIC 350763476 - already processed
# ⏭️ Skipping TIC 260043481 - already processed
# ⏭️ Skipping TIC 258658448 - already processed
# ⏭️ Skipping TIC 58019309 - already processed
# ⏭️ Skipping TIC 457088826 - already processed
# ⏭️ Skipping TIC 241049733 - already processed
# ⏭️ Skipping TIC 231198179 - already processed
# ⏭️ Skipping TIC 24250831 - already processed
# ⏭️ Skipping TIC 149472915 - already processed
# ⏭️ Skipping TIC 177307808 - already processed
# ⏭️ Skipping TIC 277869062 - already processed
# ⏭️ Skipping TIC 204697108 - already processed
# ⏭️ Skipping TIC 16419217 - already processed
# ⏭️ Skipping TIC 233040738 - already processed
# ⏭️ Skipping TIC 3808984 - already processed
# ⏭️ Skipping TIC 158551107 - already processed
# ⏭️ Skipping TIC 31306074 - already processed
# ⏭️ Skipping TIC 233684978 - already processed
# ⏭️ Skipping TIC 229774285 - already processed
# ⏭️ Skipping TIC 61383320 - already processed
# ⏭️ Skipping TIC 468333740 - already processed
# ⏭️ Skipping TIC 170882792 - already processed
# ⏭️ Skipping TIC 302792763 - already processed
# ⏭️ Skipping TIC 149269178 - already processed
# ⏭️ Skipping TIC 68076081 - already processed
# ⏭️ Skipping TIC 446952463 - already processed
# ⏭️ Skipping TIC 34086511 - already processed
# ⏭️ Skipping TIC 247045562 - already processed
# ⏭️ Skipping TIC 13623488 - already processed
# ⏭️ Skipping TIC 167333568 - already processed
# ⏭️ Skipping TIC 411256274 - already processed
# ⏭️ Skipping TIC 140687446 - already processed
# ⏭️ Skipping TIC 201797388 - already processed
# ⏭️ Skipping TIC 367095296 - already processed
# ⏭️ Skipping TIC 189637058 - already processed
# ⏭️ Skipping TIC 63291518 - already processed
# ⏭️ Skipping TIC 319431116 - already processed
# ⏭️ Skipping TIC 358788770 - already processed
# ⏭️ Skipping TIC 432191199 - already processed
# ⏭️ Skipping TIC 336196264 - already processed
# ⏭️ Skipping TIC 166075919 - already processed
# ⏭️ Skipping TIC 55380951 - already processed
# ⏭️ Skipping TIC 41089957 - already processed
# ⏭️ Skipping TIC 293412531 - already processed
# ⏭️ Skipping TIC 158569948 - already processed
# ⏭️ Skipping TIC 159891987 - already processed
# ⏭️ Skipping TIC 168705068 - already processed
# ⏭️ Skipping TIC 454014111 - already processed
# ⏭️ Skipping TIC 314976957 - already processed
# ⏭️ Skipping TIC 286684670 - already processed
# ⏭️ Skipping TIC 85998154 - already processed
# ⏭️ Skipping TIC 118800445 - already processed
# ⏭️ Skipping TIC 318019717 - already processed
# ⏭️ Skipping TIC 438325918 - already processed
# ⏭️ Skipping TIC 404017605 - already processed
# ⏭️ Skipping TIC 7221647 - already processed
# ⏭️ Skipping TIC 338930194 - already processed
# ⏭️ Skipping TIC 184297311 - already processed
# ⏭️ Skipping TIC 29277689 - already processed
# ⏭️ Skipping TIC 68489356 - already processed
# ⏭️ Skipping TIC 357791813 - already processed
# ⏭️ Skipping TIC 424813557 - already processed
# ⏭️ Skipping TIC 76089407 - already processed
# ⏭️ Skipping TIC 80128040 - already processed
# ⏭️ Skipping TIC 71152276 - already processed
# ⏭️ Skipping TIC 250976235 - already processed
# ⏭️ Skipping TIC 369984053 - already processed
# ⏭️ Skipping TIC 262176531 - already processed
# ⏭️ Skipping TIC 389925522 - already processed
# ⏭️ Skipping TIC 7579643 - already processed
# ⏭️ Skipping TIC 299833944 - already processed
# ⏭️ Skipping TIC 295447781 - already processed
# ⏭️ Skipping TIC 36692896 - already processed
# ⏭️ Skipping TIC 51937764 - already processed
# ⏭️ Skipping TIC 151733102 - already processed
# ⏭️ Skipping TIC 260657210 - already processed
# ⏭️ Skipping TIC 14078624 - already processed
# ⏭️ Skipping TIC 4339524 - already processed
# ⏭️ Skipping TIC 64069722 - already processed
# ⏭️ Skipping TIC 123321286 - already processed
# ⏭️ Skipping TIC 354649503 - already processed
# ⏭️ Skipping TIC 21579522 - already processed
# ⏭️ Skipping TIC 458547790 - already processed
# ⏭️ Skipping TIC 54490444 - already processed
# ⏭️ Skipping TIC 197248213 - already processed
# ⏭️ Skipping TIC 407613346 - already processed
# ⏭️ Skipping TIC 1354707 - already processed
# ⏭️ Skipping TIC 97413074 - already processed
# ⏭️ Skipping TIC 310845943 - already processed
# ⏭️ Skipping TIC 470750225 - already processed
# ⏭️ Skipping TIC 60289171 - already processed
# ⏭️ Skipping TIC 335948177 - already processed
# ⏭️ Skipping TIC 251181388 - already processed
# ⏭️ Skipping TIC 413298649 - already processed
# ⏭️ Skipping TIC 323007851 - already processed
# ⏭️ Skipping TIC 308599430 - already processed
# ⏭️ Skipping TIC 165764308 - already processed
# ⏭️ Skipping TIC 166005277 - already processed
# ⏭️ Skipping TIC 129864997 - already processed
# ⏭️ Skipping TIC 321436986 - already processed
# ⏭️ Skipping TIC 273855427 - already processed
# ⏭️ Skipping TIC 99097377 - already processed
# ⏭️ Skipping TIC 80984975 - already processed
# ⏭️ Skipping TIC 206473131 - already processed
# ⏭️ Skipping TIC 230086327 - already processed
# ⏭️ Skipping TIC 267602391 - already processed
# ⏭️ Skipping TIC 234498820 - already processed
# ⏭️ Skipping TIC 140237401 - already processed
# ⏭️ Skipping TIC 129953610 - already processed
# ⏭️ Skipping TIC 453122861 - already processed
# ⏭️ Skipping TIC 10756327 - already processed
# ⏭️ Skipping TIC 229888889 - already processed
# ⏭️ Skipping TIC 46530889 - already processed
# ⏭️ Skipping TIC 233511178 - already processed
# ⏭️ Skipping TIC 267757864 - already processed
# ⏭️ Skipping TIC 158013611 - already processed
# ⏭️ Skipping TIC 367839891 - already processed
# ⏭️ Skipping TIC 298666624 - already processed
# ⏭️ Skipping TIC 55603841 - already processed
# ⏭️ Skipping TIC 141823775 - already processed
# ⏭️ Skipping TIC 398305114 - already processed
# ⏭️ Skipping TIC 219798137 - already processed
# ⏭️ Skipping TIC 420128351 - already processed
# ⏭️ Skipping TIC 103724869 - already processed
# ⏭️ Skipping TIC 29514902 - already processed
# ⏭️ Skipping TIC 155639830 - already processed
# ⏭️ Skipping TIC 207400619 - already processed
# ⏭️ Skipping TIC 232970789 - already processed
# ⏭️ Skipping TIC 203149889 - already processed
# ⏭️ Skipping TIC 288410118 - already processed
# ⏭️ Skipping TIC 144503964 - already processed
# ⏭️ Skipping TIC 199617847 - already processed
# ⏭️ Skipping TIC 37593427 - already processed
# ⏭️ Skipping TIC 52038797 - already processed
# ⏭️ Skipping TIC 357099386 - already processed
# ⏭️ Skipping TIC 20542960 - already processed
# ⏭️ Skipping TIC 355206497 - already processed
# ⏭️ Skipping TIC 348516369 - already processed
# ⏭️ Skipping TIC 30938252 - already processed
# ⏭️ Skipping TIC 349311929 - already processed
# ⏭️ Skipping TIC 198178340 - already processed
# ⏭️ Skipping TIC 272188493 - already processed
# ⏭️ Skipping TIC 285990061 - already processed
# ⏭️ Skipping TIC 148159369 - already processed
# ⏭️ Skipping TIC 377017941 - already processed
# ⏭️ Skipping TIC 236759608 - already processed
# ⏭️ Skipping TIC 279362204 - already processed
# ⏭️ Skipping TIC 141609430 - already processed
# ⏭️ Skipping TIC 177386783 - already processed
# ⏭️ Skipping TIC 305300554 - already processed
# ⏭️ Skipping TIC 332303760 - already processed
# ⏭️ Skipping TIC 285357382 - already processed
# ⏭️ Skipping TIC 283785143 - already processed
# ⏭️ Skipping TIC 35703308 - already processed
# ⏭️ Skipping TIC 20897129 - already processed
# ⏭️ Skipping TIC 8259374 - already processed
# ⏭️ Skipping TIC 376851872 - already processed
# ⏭️ Skipping TIC 67422395 - already processed
# ⏭️ Skipping TIC 188589315 - already processed
# ⏭️ Skipping TIC 319151681 - already processed
# ⏭️ Skipping TIC 36692659 - already processed
# ⏭️ Skipping TIC 393779626 - already processed
# ⏭️ Skipping TIC 346976149 - already processed
# ⏭️ Skipping TIC 396478926 - already processed
# ⏭️ Skipping TIC 419903644 - already processed
# ⏭️ Skipping TIC 306825285 - already processed
# ⏭️ Skipping TIC 78193340 - already processed
# ⏭️ Skipping TIC 321601311 - already processed
# ⏭️ Skipping TIC 448585958 - already processed
# ⏭️ Skipping TIC 198182953 - already processed
# ⏭️ Skipping TIC 455859045 - already processed
# ⏭️ Skipping TIC 4739753 - already processed
# ⏭️ Skipping TIC 464586013 - already processed
# ⏭️ Skipping TIC 1980968952 - already processed
# ⏭️ Skipping TIC 441811910 - already processed
# ⏭️ Skipping TIC 372361075 - already processed
# ⏭️ Skipping TIC 2886827 - already processed
# ⏭️ Skipping TIC 9261780 - already processed
# ⏭️ Skipping TIC 219742885 - already processed
# ⏭️ Skipping TIC 245910918 - already processed
# ⏭️ Skipping TIC 139054267 - already processed
# ⏭️ Skipping TIC 159455588 - already processed
# ⏭️ Skipping TIC 31963696 - already processed
# ⏭️ Skipping TIC 289625888 - already processed
# ⏭️ Skipping TIC 388013620 - already processed
# ⏭️ Skipping TIC 317154006 - already processed
# ⏭️ Skipping TIC 396899011 - already processed
# ⏭️ Skipping TIC 123629801 - already processed
# ⏭️ Skipping TIC 392963383 - already processed
# ⏭️ Skipping TIC 197829751 - already processed
# ⏭️ Skipping TIC 165534243 - already processed
# ⏭️ Skipping TIC 468990102 - already processed
# ⏭️ Skipping TIC 364129168 - already processed
# ⏭️ Skipping TIC 735872456 - already processed
# ⏭️ Skipping TIC 457088541 - already processed
# ⏭️ Skipping TIC 250418045 - already processed
# ⏭️ Skipping TIC 219776326 - already processed
# ⏭️ Skipping TIC 367856400 - already processed
# ⏭️ Skipping TIC 357526359 - already processed
# ⏭️ Skipping TIC 237217129 - already processed
# ⏭️ Skipping TIC 206462744 - already processed
# ⏭️ Skipping TIC 233233994 - already processed
# ⏭️ Skipping TIC 219792161 - already processed
# ⏭️ Skipping TIC 376847337 - already processed
# ⏭️ Skipping TIC 243333942 - already processed
# ⏭️ Skipping TIC 237203318 - already processed
# ⏭️ Skipping TIC 233238892 - already processed
# ⏭️ Skipping TIC 99568328 - already processed
# ⏭️ Skipping TIC 121713574 - already processed
# ⏭️ Skipping TIC 222012610 - already processed
# ⏭️ Skipping TIC 61090239 - already processed
# ⏭️ Skipping TIC 265576346 - already processed
# ⏭️ Skipping TIC 233187169 - already processed
# ⏭️ Skipping TIC 169763950 - already processed
# ⏭️ Skipping TIC 219845970 - already processed
# ⏭️ Skipping TIC 307956984 - already processed
# ⏭️ Skipping TIC 220389494 - already processed
# ⏭️ Skipping TIC 167010837 - already processed
# ⏭️ Skipping TIC 309756397 - already processed
# ⏭️ Skipping TIC 370883476 - already processed
# ⏭️ Skipping TIC 119612992 - already processed
# ⏭️ Skipping TIC 61571860 - already processed
# ⏭️ Skipping TIC 219014771 - already processed
# ⏭️ Skipping TIC 198208345 - already processed
# ⏭️ Skipping TIC 160585734 - already processed
# ⏭️ Skipping TIC 399788653 - already processed
# ⏭️ Skipping TIC 149390282 - already processed
# ⏭️ Skipping TIC 313422679 - already processed
# ⏭️ Skipping TIC 416449791 - already processed
# ⏭️ Skipping TIC 229958602 - already processed
# ⏭️ Skipping TIC 160073241 - already processed
# ⏭️ Skipping TIC 287772494 - already processed
# ⏭️ Skipping TIC 341873828 - already processed
# ⏭️ Skipping TIC 40534681 - already processed
# ⏭️ Skipping TIC 48354338 - already processed
# ⏭️ Skipping TIC 287152402 - already processed
# ⏭️ Skipping TIC 247117382 - already processed
# ⏭️ Skipping TIC 137810850 - already processed
# ⏭️ Skipping TIC 123230837 - already processed
# ⏭️ Skipping TIC 396196505 - already processed
# ⏭️ Skipping TIC 259097905 - already processed
# ⏭️ Skipping TIC 232648441 - already processed
# ⏭️ Skipping TIC 7854956 - already processed
# ⏭️ Skipping TIC 13222066 - already processed
# ⏭️ Skipping TIC 288526512 - already processed
# ⏭️ Skipping TIC 396721876 - already processed
# ⏭️ Skipping TIC 372943067 - already processed
# ⏭️ Skipping TIC 329594833 - already processed
# ⏭️ Skipping TIC 233046041 - already processed
# ⏭️ Skipping TIC 198355046 - already processed
# ⏭️ Skipping TIC 357099320 - already processed
# ⏭️ Skipping TIC 307780260 - already processed
# ⏭️ Skipping TIC 219763205 - already processed
# ⏭️ Skipping TIC 362225924 - already processed
# ⏭️ Skipping TIC 410486078 - already processed
# ⏭️ Skipping TIC 267542850 - already processed
# ⏭️ Skipping TIC 229496201 - already processed
# ⏭️ Skipping TIC 237097047 - already processed
# ⏭️ Skipping TIC 166178948 - already processed
# ⏭️ Skipping TIC 402659180 - already processed
# ⏭️ Skipping TIC 356895908 - already processed
# ⏭️ Skipping TIC 229675482 - already processed
# ⏭️ Skipping TIC 441761546 - already processed
# ⏭️ Skipping TIC 441723394 - already processed
# ⏭️ Skipping TIC 306742226 - already processed
# ⏭️ Skipping TIC 229583294 - already processed
# ⏭️ Skipping TIC 406855037 - already processed
# ⏭️ Skipping TIC 34162347 - already processed
# ⏭️ Skipping TIC 333783222 - already processed
# ⏭️ Skipping TIC 230088977 - already processed
# ⏭️ Skipping TIC 462549964 - already processed
# ⏭️ Skipping TIC 233052755 - already processed
# ⏭️ Skipping TIC 309249660 - already processed
# ⏭️ Skipping TIC 288268709 - already processed
# ⏭️ Skipping TIC 382267347 - already processed
# ⏭️ Skipping TIC 270500845 - already processed
# ⏭️ Skipping TIC 48523426 - already processed
# ⏭️ Skipping TIC 219850059 - already processed
# ⏭️ Skipping TIC 262086858 - already processed
# ⏭️ Skipping TIC 219696326 - already processed
# ⏭️ Skipping TIC 153590137 - already processed
# ⏭️ Skipping TIC 39934753 - already processed
# ⏭️ Skipping TIC 387195344 - already processed
# ⏭️ Skipping TIC 46898083 - already processed
# ⏭️ Skipping TIC 389402815 - already processed
# ⏭️ Skipping TIC 235928358 - already processed
# ⏭️ Skipping TIC 345045396 - already processed
# ⏭️ Skipping TIC 284203583 - already processed
# ⏭️ Skipping TIC 393672127 - already processed
# ⏭️ Skipping TIC 236431137 - already processed
# ⏭️ Skipping TIC 462512239 - already processed
# ⏭️ Skipping TIC 457919571 - already processed
# ⏭️ Skipping TIC 211589331 - already processed
# ⏭️ Skipping TIC 47091300 - already processed
# ⏭️ Skipping TIC 195192488 - already processed
# ⏭️ Skipping TIC 263709584 - already processed
# ⏭️ Skipping TIC 286507518 - already processed
# ⏭️ Skipping TIC 198206376 - already processed
# ⏭️ Skipping TIC 327668334 - already processed
# ⏭️ Skipping TIC 147970592 - already processed
# ⏭️ Skipping TIC 161723026 - already processed
# ⏭️ Skipping TIC 291557980 - already processed
# ⏭️ Skipping TIC 235558459 - already processed
# ⏭️ Skipping TIC 183645169 - already processed
# ⏭️ Skipping TIC 160407906 - already processed
# ⏭️ Skipping TIC 273848297 - already processed
# ⏭️ Skipping TIC 236767930 - already processed
# ⏭️ Skipping TIC 238174284 - already processed
# ⏭️ Skipping TIC 366380782 - already processed
# ⏭️ Skipping TIC 279743597 - already processed
# ⏭️ Skipping TIC 160604654 - already processed
# ⏭️ Skipping TIC 141683638 - already processed
# ⏭️ Skipping TIC 140864719 - already processed
# ⏭️ Skipping TIC 286063431 - already processed
# ⏭️ Skipping TIC 219824200 - already processed
# ⏭️ Skipping TIC 160082676 - already processed
# ⏭️ Skipping TIC 67718311 - already processed
# ⏭️ Skipping TIC 275156928 - already processed
# ⏭️ Skipping TIC 354442089 - already processed
# ⏭️ Skipping TIC 288959702 - already processed
# ⏭️ Skipping TIC 417583197 - already processed
# ⏭️ Skipping TIC 31675050 - already processed
# ⏭️ Skipping TIC 396389606 - already processed
# ⏭️ Skipping TIC 358071448 - already processed
# ⏭️ Skipping TIC 237350192 - already processed
# ⏭️ Skipping TIC 321813588 - already processed
# ⏭️ Skipping TIC 270173850 - already processed
# ⏭️ Skipping TIC 394973078 - already processed
# ⏭️ Skipping TIC 436617458 - already processed
# ⏭️ Skipping TIC 284593129 - already processed
# ⏭️ Skipping TIC 145877004 - already processed
# ⏭️ Skipping TIC 273577061 - already processed
# ⏭️ Skipping TIC 71594657 - already processed
# ⏭️ Skipping TIC 277328612 - already processed
# ⏭️ Skipping TIC 388238555 - already processed
# ⏭️ Skipping TIC 1551425931 - already processed
# ⏭️ Skipping TIC 233060935 - already processed
# ⏭️ Skipping TIC 264172101 - already processed
# ⏭️ Skipping TIC 400406712 - already processed
# ⏭️ Skipping TIC 70596114 - already processed
# ⏭️ Skipping TIC 293281733 - already processed
# ⏭️ Skipping TIC 268529531 - already processed
# ⏭️ Skipping TIC 287192872 - already processed
# ⏭️ Skipping TIC 140894354 - already processed
# ⏭️ Skipping TIC 167720952 - already processed
# ⏭️ Skipping TIC 462549964 - already processed
# ⏭️ Skipping TIC 233052755 - already processed
# ⏭️ Skipping TIC 309249660 - already processed
# ⏭️ Skipping TIC 288268709 - already processed
# ⏭️ Skipping TIC 382267347 - already processed
# ⏭️ Skipping TIC 270500845 - already processed
# ⏭️ Skipping TIC 48523426 - already processed
# ⏭️ Skipping TIC 219850059 - already processed
# ⏭️ Skipping TIC 262086858 - already processed
# ⏭️ Skipping TIC 219696326 - already processed
# ⏭️ Skipping TIC 153590137 - already processed
# ⏭️ Skipping TIC 39934753 - already processed
# ⏭️ Skipping TIC 387195344 - already processed
# ⏭️ Skipping TIC 46898083 - already processed
# ⏭️ Skipping TIC 389402815 - already processed
# ⏭️ Skipping TIC 235928358 - already processed
# ⏭️ Skipping TIC 345045396 - already processed
# ⏭️ Skipping TIC 284203583 - already processed
# ⏭️ Skipping TIC 393672127 - already processed
# ⏭️ Skipping TIC 236431137 - already processed
# ⏭️ Skipping TIC 462512239 - already processed
# ⏭️ Skipping TIC 457919571 - already processed
# ⏭️ Skipping TIC 211589331 - already processed
# ⏭️ Skipping TIC 47091300 - already processed
# ⏭️ Skipping TIC 195192488 - already processed
# ⏭️ Skipping TIC 263709584 - already processed
# ⏭️ Skipping TIC 286507518 - already processed
# ⏭️ Skipping TIC 198206376 - already processed
# ⏭️ Skipping TIC 327668334 - already processed
# ⏭️ Skipping TIC 147970592 - already processed
# ⏭️ Skipping TIC 161723026 - already processed
# ⏭️ Skipping TIC 291557980 - already processed
# ⏭️ Skipping TIC 235558459 - already processed
# ⏭️ Skipping TIC 183645169 - already processed
# ⏭️ Skipping TIC 160407906 - already processed
# ⏭️ Skipping TIC 273848297 - already processed
# ⏭️ Skipping TIC 236767930 - already processed
# ⏭️ Skipping TIC 238174284 - already processed
# ⏭️ Skipping TIC 366380782 - already processed
# ⏭️ Skipping TIC 279743597 - already processed
# ⏭️ Skipping TIC 160604654 - already processed
# ⏭️ Skipping TIC 141683638 - already processed
# ⏭️ Skipping TIC 140864719 - already processed
# ⏭️ Skipping TIC 286063431 - already processed
# ⏭️ Skipping TIC 219824200 - already processed
# ⏭️ Skipping TIC 160082676 - already processed
# ⏭️ Skipping TIC 67718311 - already processed
# ⏭️ Skipping TIC 275156928 - already processed
# ⏭️ Skipping TIC 354442089 - already processed
# ⏭️ Skipping TIC 288959702 - already processed
# ⏭️ Skipping TIC 417583197 - already processed
# ⏭️ Skipping TIC 31675050 - already processed
# ⏭️ Skipping TIC 396389606 - already processed
# ⏭️ Skipping TIC 358071448 - already processed
# ⏭️ Skipping TIC 237350192 - already processed
# ⏭️ Skipping TIC 321813588 - already processed
# ⏭️ Skipping TIC 270173850 - already processed
# ⏭️ Skipping TIC 394973078 - already processed
# ⏭️ Skipping TIC 436617458 - already processed
# ⏭️ Skipping TIC 284593129 - already processed
# ⏭️ Skipping TIC 145877004 - already processed
# ⏭️ Skipping TIC 273577061 - already processed
# ⏭️ Skipping TIC 71594657 - already processed
# ⏭️ Skipping TIC 277328612 - already processed
# ⏭️ Skipping TIC 388238555 - already processed
# ⏭️ Skipping TIC 1551425931 - already processed
# ⏭️ Skipping TIC 233060935 - already processed
# ⏭️ Skipping TIC 264172101 - already processed
# ⏭️ Skipping TIC 400406712 - already processed
# ⏭️ Skipping TIC 70596114 - already processed
# ⏭️ Skipping TIC 293281733 - already processed
# ⏭️ Skipping TIC 268529531 - already processed
# ⏭️ Skipping TIC 287192872 - already processed
# ⏭️ Skipping TIC 140894354 - already processed
# ⏭️ Skipping TIC 167720952 - already processed
# WARNING: File may have been truncated: actual file length (65536) is smaller than the expected size (146880) [astropy.io.fits.file]
